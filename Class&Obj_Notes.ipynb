# %% [markdown]
# #### <b>Create a Class</b>
#
# To create a class, use the keyword ```class```:
#
# Create a class named MyClass, with a property named msg:
#
# #### <b> Create Object</b>
#
# Now we can use the class named ```MyClass``` to create objects:
#
# Create an ```object``` named ```obj1```, and print the value of msg:

# %%
class MyClass:
  msg = 'Hello!'
obj1 = MyClass()
print(obj1.msg)
# Out:
# Hello!

# %% [markdown]
# ### The __init__() Function
#
# * The example above are classe and object in their simplest form, and are not really useful in real life applications.
#
# * To understand the meaning of classe we have to understand the built-in``` __init__()``` function.
#
# * All classes have a function called``` __init__()```, which is always executed when the class is being initiated.
#
# * Use the ```__init__()``` function to assign values to object properties, or other operations that are necessary to do when the object is being created:
#
# <b>Example:</b>
#
# * Create a class named Employee, use the``` __init__()``` function to assign values for name, gender and designation.
#
# * The ```self``` parameter is a reference to the current instance of the class, and is used to access variables that belongs to the class.
#
# * It does not have to be named ```self``` , you can call it whatever you like, but it has to be the first parameter of any function in the class.
#
# <b>Note:</b>The ```__init__()``` function is called automatically every time the class is being used to create a new object.

# %%
class Employee:
  def __init__(self, name, gender,designation):
    self.name = name
    self.gender = gender
    self.designation=designation

emp = Employee("Mahender", "Male","Software Engineer")

print(emp.name)
print(emp.gender)
print(emp.designation)
# Out:
# Mahender
# Male
# Software Engineer

# %%
# creating a class
class Intern:
  pass

# %%
# object instantiation
mahe=Intern()

# %%
def foo():
  print('Hello')
  return 100

# %%
x=foo() # fun calling and assigning to variale
x
# Out:
# Hello

# %%
def foo():         #obj insta & fun calling not same
  #print('Hello')
  return 100

# %%
y=foo()
y
# Out:
# 100

# %%
print(type(mahe))
print(type(x))
# Out:
# <class '__main__.Intern'>
# <class 'NoneType'>

# %%
mahe.fname='mahender' # 3 fields
mahe.lname='narra'
mahe.age=35

# %%
vihaan=Intern()
vihaan.fulname='Vihaan Reddy' # new 3 more
vihaan.lstname='narra'
vihaan.age_no=5

# %%
mahe.fname
# Out:
# 'mahender'

# %%
vihaan.fulname
# Out:
# 'Vihaan Reddy'

# %%
class Employee:
  def basicDetails(self,fname,lname,age,gender):
    self.firstname=fname
    self.lastname=lname
    self.age_no=age
    self.genderr=gender

# %%
mahender=Employee() # object created - mahender

# %%
mahender.basicDetails('mahender reddy','narra',35,'Male')

# %%
mahender.age_no
# Out:
# 35

# %%
#vinnu=Employee()

# %%
# Employee.basicDetails() un comment to see error

# %%
Employee.basicDetails(vinnu,'vihaanReddy','narra',5,'male')

# %%
vinnu.basicDetails
# Out:
# <bound method Employee.basicDetails of <__main__.Employee object at 0x790f614f32e0>>

# %%
vinnu.firstname
# Out:
# 'vihaanReddy'

# %%
class Student:
  def __init__(self,fname,lname,age,course):
    self.ftname=fname
    self.ltname=lname
    self.age_n=age
    self.cours=course

# %%
vihan=Student('vinn','n',5,'UKG')

# %%
vihan

# %%
vihan.cours
# Out:
# 'UKG'
