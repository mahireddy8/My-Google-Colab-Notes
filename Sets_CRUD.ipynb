# %% [markdown]
# ### <b>Set: </b> A set is a collection which is un sequentail, unordered, mutable , and unindexed.
#
# * duplicates are not allowed

# %%
# create: using {} and set() constructor
set1={0,1,'abc',1.25,True,False,bool,4+6j}

# %%
set1 # True, false won't print bcz 1-t,0-f, print unorder so no indexing
# Out:
# {(4+6j), 0, 1, 1.25, bool, 'abc'}

# %%
print(set1)
# Out:
# {0, 1, 1.25, <class 'bool'>, (4+6j), 'abc'}

# %%
len(set1)
# Out:
# 6

# %%
set2=set(("apple", "banana", "cherry"))
print(type(set2))
# Out:
# <class 'set'>

# %%
#Accessing/ reading
for i in set2:
  print(i)
# Out:
# apple
# banana
# cherry

# %%
print('banana' in set2)
# Out:
# True

# %%
print('banana' not in set2)
# Out:
# False

# %%
set2.add('orange')
set2
# Out:
# {'apple', 'banana', 'cherry', 'orange'}

# %%
# update
veg={'tomato','brijal','beetroot'}
set2.update(veg)
set2
# Out:
# {'apple', 'banana', 'beetroot', 'brijal', 'cherry', 'orange', 'tomato'}

# %%
mylist = ["kiwi", "orange"]
set2.update(mylist)
set2
# Out:
# {'apple', 'banana', 'beetroot', 'brijal', 'cherry', 'kiwi', 'orange', 'tomato'}

# %%
# remove
set2.remove('brijal')
set2
# Out:
# {'apple', 'banana', 'beetroot', 'cherry', 'kiwi', 'orange', 'tomato'}

# %%
set2.discard("banana")
set2
# Out:
# {'apple', 'beetroot', 'cherry', 'kiwi', 'orange', 'tomato'}

# %%
set2.discard("banana") # it won't raise any error

# %%
#set2.remove('banana') # if element not found it raise an error

# %%
for x in set2:
  print(x)
# Out:
# beetroot
# tomato
# kiwi
# cherry
# apple
# orange

# %% [markdown]
# ### <b>Join Sets:</b>
# * There are several ways to join two or more sets in Python.
#
# * The union() and update() methods joins all items from both sets.
#
# * The intersection() method keeps ONLY the duplicates.(common values in two sets)
#
# * The difference() method keeps the items from the first set that are not in the other set(s).
#
# * The symmetric_difference() method keeps all items EXCEPT the duplicates.

# %%
# uion
set1 = {"a", "b", "c",1,3}
set2 = {1, 2, 3,'a','c'}
res=set1.union(set2)
print(res)
# Out:
# {1, 2, 3, 'a', 'b', 'c'}

# %%
# intersection
res1=set1.intersection(set2)
res1
# Out:
# {1, 3, 'a', 'c'}

# %%
# difference (set1,set2)
diff=set1.difference(set2)
diff
# Out:
# {'b'}

# %%
# symmetric difference (set1,set2)
sy_diff=set1.symmetric_difference(set2)
sy_diff
# Out:
# {2, 'b'}

# %%
# difference_update()
set1=set1.difference_update(set2)

# %%
set1

# %%
set2
# Out:
# {1, 2, 3, 'a', 'c'}

# %%
set1={'a',10,'b',1}

# %%
set1.pop()
# Out:
# 'b'

# %%
set1.pop()
# Out:
# 'a'

# %%
set1.clear()

# %%
set1
# Out:
# set()
