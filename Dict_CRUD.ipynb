# %% [markdown]
# ### <b>Dictionary:</b>
#
# * Dictionaries are used to store data values in key:value pairs.
# * The values in dictionary items can be of any data type:
# * A dictionary is a collection which is ordered*, changeable and do not allow duplicates.
# * Dictionaries are written with curly brackets, and have keys and values:
# * dictionaty keys should be unique but values can be duplicate

# %%
d1={'a':1,'b':2,'c':3}
d2=dict({1:'one',2:'two',3:'three',1:'hi'})
print(d1,type(d1))
print(d2,type(d2))
# Out:
# {'a': 1, 'b': 2, 'c': 3} <class 'dict'>
# {1: 'hi', 2: 'two', 3: 'three'} <class 'dict'>

# %%
car={"brand": "Ford","model": "Mustang","year": 1964,"year": 2020} # repeated last value will add in dictionary
car,len(car)
# Out:
# ({'brand': 'Ford', 'model': 'Mustang', 'year': 2020}, 3)
