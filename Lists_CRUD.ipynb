# %% [markdown]
# ### <b> Data structures in Python: </b>
# * Lists
# * Tuples
# * sets
# *dictionaries

# %% [markdown]
# ### <b>CRUD Operations in Data structures:</b>
# * create
# * read
# * update
# * delete

# %% [markdown]
# ### <b>1. List: Lists are used to store multiple items in a single variable</b>
#   - <u>Create :</u> by using [ ] or by using list( ) constructer/ funtion
#   - <u> Read :</u>
#
#     * indexing
#     * slicing
#     * zip()
#     * loop
#     * list comprehension
#     * enumerate
#
# - <u>Update: </u>
#
#     *  append()
#     *  extend()
#     * insert()
#     * reverse()
#     * sort()
#
# - <u> Delete: </u>
#
#    *  pop()
#    *  remove()
#    *  clear()

# %%
list1=[1,2,3,4,5]
list2=list(['a','b','c','d','e'])

# %%
print(list1,type(list1))
print(list2,type(list2))
# Out:
# [1, 2, 3, 4, 5] <class 'list'>
# ['a', 'b', 'c', 'd', 'e'] <class 'list'>

# %%
print(list1[4],list1[-1],list1[0:4])
# Out:
# 5 5 [1, 2, 3, 4]

# %%
print(list2[0:4:2])
print(list1[::])
print(list2[::-1])
# Out:
# ['a', 'c']
# [1, 2, 3, 4, 5]
# ['e', 'd', 'c', 'b', 'a']

# %%
for ele in list1:
  print(ele)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
[i for i in list2]
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
fruits = ["apple", "banana", "cherry"]
if "apple" in fruits:
  print("Yes, 'apple' is in the fruits list")
# Out:
# Yes, 'apple' is in the fruits list

# %%
#updating
fruits[0]="pineapple"
fruits
# Out:
# ['pineapple', 'banana', 'cherry']

# %%
fruits[1:2]=('dragon-fruit','avacado')
fruits
# Out:
# ['pineapple', 'dragon-fruit', 'avacado', 'cherry']

# %%
fruits.insert(0,"Apple")
fruits
# Out:
# ['Apple', 'pineapple', 'dragon-fruit', 'avacado', 'cherry']

# %%
fruits.append("orange")
fruits
# Out:
# ['Apple', 'pineapple', 'dragon-fruit', 'avacado', 'cherry', 'orange']

# %%
fruits.insert(3,'orange')
fruits
# Out:
# ['Apple',
#  'pineapple',
#  'dragon-fruit',
#  'orange',
#  'orange',
#  'avacado',
#  'cherry',
#  'orange']

# %%
print(fruits)
# Out:
# ['Apple', 'pineapple', 'dragon-fruit', 'orange', 'orange', 'avacado', 'cherry', 'orange']

# %%
tropical_fruits= ["mango", "pineapple", "papaya"]
fruits.extend(tropical_fruits)
print(fruits)
# Out:
# ['Apple', 'pineapple', 'dragon-fruit', 'orange', 'orange', 'avacado', 'cherry', 'orange', 'mango', 'pineapple', 'papaya']

# %%
fruits.remove('orange')
fruits
# Out:
# ['Apple',
#  'pineapple',
#  'dragon-fruit',
#  'orange',
#  'avacado',
#  'cherry',
#  'orange',
#  'mango',
#  'pineapple',
#  'papaya']

# %%
fruits.pop(7)
fruits
# Out:
# ['Apple',
#  'pineapple',
#  'dragon-fruit',
#  'orange',
#  'avacado',
#  'cherry',
#  'orange',
#  'pineapple',
#  'papaya']

# %%
fruits.pop() # last item will delete
fruits
# Out:
# ['Apple',
#  'pineapple',
#  'dragon-fruit',
#  'orange',
#  'avacado',
#  'cherry',
#  'orange',
#  'pineapple']

# %%
del fruits[4]
fruits
# Out:
# ['Apple',
#  'pineapple',
#  'dragon-fruit',
#  'orange',
#  'cherry',
#  'orange',
#  'pineapple']

# %%
del fruits

# %%
# fruits uncomment to see error

# %%
list1
# Out:
# [1, 2, 3, 4, 5]

# %%
list1.clear()

# %%
list1
# Out:
# []

# %%
list2
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
for i in range(len(list2)):
  print(list2[i])
# Out:
# a
# b
# c
# d
# e

# %%
vegetables=['tomato','brinjal','okra','bottle gaurd','onion']
i=0
while i<len(vegetables):
  print(i,vegetables[i])
  i=i+1
# Out:
# 0 tomato
# 1 brinjal
# 2 okra
# 3 bottle gaurd
# 4 onion

# %%
[veg for veg in vegetables]
# Out:
# ['tomato', 'brinjal', 'okra', 'bottle gaurd', 'onion']

# %%
new_list=[]
for i in vegetables:
  if i in vegetables:
    new_list.append(i)
print(new_list)
# Out:
# ['tomato', 'brinjal', 'okra', 'bottle gaurd', 'onion']

# %%
new_list1=[ x for x in new_list if x in new_list ]

# %%
new_list1
# Out:
# ['tomato', 'brinjal', 'okra', 'bottle gaurd', 'onion']

# %%
nl=[i for i in new_list if i !='brinjal']
nl
# Out:
# ['tomato', 'okra', 'bottle gaurd', 'onion']

# %%
nl2=[i for i in vegetables]
nl2
# Out:
# ['tomato', 'brinjal', 'okra', 'bottle gaurd', 'onion']

# %%
nl3=[i for i in range(5)]
nl3
# Out:
# [0, 1, 2, 3, 4]

# %%
nn=[i for i in range(10) if i>5]
nn
# Out:
# [6, 7, 8, 9]

# %%
cap_veg=[i.upper() for i in vegetables ]
print(cap_veg)
# Out:
# ['TOMATO', 'BRINJAL', 'OKRA', 'BOTTLE GAURD', 'ONION']

# %%
fruits=['apple','banana','chery','orange','kiwi']
newlist = [x if x != "banana" else "orange" for x in fruits]
newlist
# Out:
# ['apple', 'orange', 'chery', 'orange', 'kiwi']

# %%
fruits=['apple','chery','orange','kiwi']
up_list = [x if x != "orange" else "avacado" for x in fruits]
up_list
# Out:
# ['apple', 'chery', 'avacado', 'kiwi']

# %%
fruits.sort()

# %%
fruits
# Out:
# ['apple', 'chery', 'kiwi', 'orange']

# %%
l11=[100,23,4,0,99,56]
l11.sort()  # sort by default ascending order
l11
# Out:
# [0, 4, 23, 56, 99, 100]

# %%
# descending order
l11.sort(reverse=True)
l11
# Out:
# [100, 99, 56, 23, 4, 0]

# %% [markdown]
# ### Customize Sort Function
# * You can also customize your own function by using the keyword argument key = function.
#
# * The function will return a number that will be used to sort the list (the lowest number first):

# %%
def myfunc(n):
  return abs(n - 50)

thislist = [100, 50, 65, 82, 23]

thislist.sort(key = myfunc)

print(thislist)
# Out:
# [50, 65, 23, 82, 100]

# %% [markdown]
# ### Case Insensitive Sort
#
# - By default the sort() method is case sensitive, resulting in all capital letters being sorted before lower case letters:
#
# - Case sensitive sorting can give an unexpected result:
#
# - Luckily we can use built-in functions as key functions when sorting a list.
# - So if you want a case-insensitive sort function, use<b> str.lower</b> as a key function:

# %%
fruits= ["banana", "Orange", "Kiwi", "cherry"]
fruits.sort()
fruits
# Out:
# ['Kiwi', 'Orange', 'banana', 'cherry']

# %%
fruits.sort(key = str.lower)
fruits
# Out:
# ['banana', 'cherry', 'Kiwi', 'Orange']

# %%
fruits.reverse()
fruits
# Out:
# ['Orange', 'Kiwi', 'cherry', 'banana']

# %%
mylist=fruits.copy()
mylist
# Out:
# ['Orange', 'Kiwi', 'cherry', 'banana']

# %%
# using list()method
nl=list(fruits)
nl
# Out:
# ['Orange', 'Kiwi', 'cherry', 'banana']

# %% [markdown]
# ### Join Two Lists:
# * using + operator
# * by appending all the items from list2 into list1, one by one

# %%
l1=['a','b','c']
l2=[1,2,3]
for i in l2:
  l1.append(i)
print(l1)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
l3=l2+l1
print(l3)
# Out:
# [1, 2, 3, 'a', 'b', 'c', 1, 2, 3]

# %%
l4=l1+l2
l4
# Out:
# ['a', 'b', 'c', 1, 2, 3, 1, 2, 3]

# %%
l1.extend(l2)
l1
# Out:
# ['a', 'b', 'c', 1, 2, 3, 1, 2, 3]
