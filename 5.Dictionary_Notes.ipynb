# %% [markdown]
# ### Dictionary
#
# * Dictionaries are used to store data values in key:value pairs.
#
# * A dictionary is a collection which is ordered*, changeable and do not allow duplicates.
# * It is a collection of key value pair
# * it is denoting with flower braces
# * indexing is possible in Dictionary, key will be act as an index
# * keys should be unique ( not duplication allowed )
# * values can be duplicated
#
# <b>Note: </b>As of Python version 3.7, dictionaries are ordered. In Python 3.6 and earlier, dictionaries are unordered.

# %%
# {key:value}
d={'1':'one','2':'two','3':'three'}

# %%
d,len(d)
# Out:
# ({'1': 'one', '2': 'two', '3': 'three'}, 3)

# %%
d1={1:'one',2:'two',3:'three'}

# %%
d1
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
d2=dict()
d2, type(d2)
# Out:
# ({}, dict)

# %%
a=[]
b=()
c={}
d=set()
print(type(a),type(b),type(c),type(d))
# Out:
# <class 'list'> <class 'tuple'> <class 'dict'> <class 'set'>

# %%
d={'a':11,'b':22,'c':33,'a':00}

# %%
d
# Out:
# {'a': 0, 'b': 22, 'c': 33}

# %%
d1={'a':11,'b':22,'c':33,'a':1000}

# %%
d1
# Out:
# {'a': 1000, 'b': 22, 'c': 33}

# %%
d1={'a':11,'b':22,'c':33,'c':11}

# %%
d1
# Out:
# {'a': 11, 'b': 22, 'c': 11}

# %% [markdown]
# ### Accessing elements

# %%
d['c']
# Out:
# 33

# %%
d
# Out:
# {'a': 0, 'b': 22, 'c': 33}

# %% [markdown]
# ### get()
# * Note: get () will not through any error even the key is not vailable

# %%
e=d.get('a')
e
# Out:
# 0

# %%
d['e']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-06ba894b5834> in <cell line: 1>()
# ----> 1 d['e']
#
# KeyError: 'e'

# %%
d.get('e') # it doesn't raise any exception/error

# %%
d1.keys()
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
d1.values()
# Out:
# dict_values([11, 22, 11])

# %%
d.items()
# Out:
# dict_items([('a', 0), ('b', 22), ('c', 33)])

# %%
len(d)
# Out:
# 3

# %% [markdown]
# #### Add elements

# %%
d
# Out:
# {'a': 0, 'b': 22, 'c': 33}

# %%
d['a']
# Out:
# 0

# %%
d[3]="d"

# %%
d
# Out:
# {'a': 0, 'b': 22, 'c': 33, 3: 'd'}

# %%
d['a']=9999

# %%
d
# Out:
# {'a': 9999, 'b': 22, 'c': 33, 3: 'd'}

# %% [markdown]
# #### update()

# %%
d.update({'eee':8888})

# %%
d
# Out:
# {'a': 9999, 'b': 22, 'c': 33, 3: 'd', 'eee': 8888}

# %% [markdown]
# #### delete elements: pop(), popitem(),del

# %%
# pop() used to delete specified value
d.pop(3)
# Out:
# 'd'

# %%
d
# Out:
# {'a': 9999, 'b': 22, 'c': 33, 'eee': 8888}

# %%
# Pop item() used to delete last item
d.popitem()
# Out:
# ('eee', 8888)

# %%
del d['a']

# %%
d
# Out:
# {'b': 22, 'c': 33}

# %%
del d # it delete complete dictionary along with all keys:values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-47b9ec324be6> in <cell line: 1>()
# ----> 1 del d # it delete complete dictionary along with all keys:values
#
# NameError: name 'd' is not defined

# %% [markdown]
# ### DIff b/w sets{} and dict{}
# * set not accept uplicates in dict it allows
# * set unindexed, dict indexed
# * sets are unordered, dict also unordered

# %% [markdown]
# ### Dictionary Methods
#
# * <b>clear( )</b>	Removes all the elements from the dictionary
# * <b>copy( )</b>	Returns a copy of the dictionary
# * <b>fromkeys( )</b>	Returns a dictionary with the specified keys and value
# * <b>get( )</b>	Returns the value of the specified key
# * <b>items( )</b>	Returns a list containing a tuple for each key value pair
# * <b>keys( )</b>	Returns a list containing the dictionary's keys
# * <b>pop( )</b>	Removes the element with the specified key
# * <b>popitem( )</b>	Removes the last inserted key-value pair
# * <b>setdefault( )</b>	Returns the value of the specified key. If the key does not
# * <b>exist( )</b> insert the key, with the specified value
# * <b>update( )</b>	Updates the dictionary with the specified key-value pairs
# * <b>values( )</b>	Returns a list of all the values in the dictionary

# %%
d1
# Out:
# {'a': 11, 'b': 22, 'c': 11}
